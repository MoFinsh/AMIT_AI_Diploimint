# %%
members = {
    "Mohamed":{"age":"22","gender":"male", "Skills":{"HTML":"90%","CSS":"80%","JS":"85%"}},
    "Abdo":{"age":"20","gender":"male", "Skills":{"HTML":"80%","CSS":"90%","JS":"70%"}},
    "Nour":{"age":"21","gender":"female", "Skills":{"HTML":"85%","CSS":"70%","JS":"90%"}}
    }

new_member = input("enter your name").strip()
print(new_member)
if new_member in members:
        print (f"welcome MR.{new_member} , do you want to edit your skills ? ")
        result = input("Yes or No").strip().lower()

        if result =="yes" or result =="y":
            user_skill = input("select your skill to Edit").strip().upper()
            members[new_member]["Skills"][user_skill] = input("enter your Percentage")+"%"
        
            print("do you want to edit another skill")
            new_edit = input(" 'Yes' or 'No' ").strip().lower()

            while new_edit == "y" or new_edit =="yes":
                user_skill = input("select your skill to Edit").strip().upper()
                members[new_member]["Skills"][user_skill] = input("enter your Percentage")+"%"

                print("do you want to edit another skill")
                new_edit = input(" 'Yes' or 'No' ").strip().lower()
           
                 
        else:
            print("welcome to combany")

else:
        print(f"sorry MR.{new_member} you are not in database \nDo you want to enter your data ?")
        action = input(" Yes or No ")
        if action =="yes" or action =="y":
            print("enter your name : ")
            name = input("enter your name : ").strip().capitalize()
            print(name)

            print("enter your age : ")
            age = int(input("enter your age : "))
            str_age = str(age)
            print(age)

            print("enter your gender : ")
            gender = input("enter your gender : ")
            print(gender)

            def get_key_value(dect,key,value):
                dect[key]=value

            Skills = {}
            print("enter your Skill : ")
            Skill = input("enter your Skill : ").strip().upper()
            print("enter skill Percentage")
            Percentage = int(input("enter skill Percentage"))
            str_percentage = str(Percentage)+"%"
            print(f"{Skill}{str_percentage}")
            
            get_key_value(Skills,Skill,str_percentage)

            print("have another skills ?")
            quition = input("Yes or No").strip().lower()

            while quition =="yes" or quition =="y":
                print("enter another Skill : ")
                Skill = input("enter your Skill : ").strip().upper()
                print("enter skill Percentage")
                Percentage = int(input("enter skill Percentage"))
                str_percentage = str(Percentage)+"%"

                get_key_value(Skills,Skill,str_percentage)

                print(f"{Skill}{str_percentage}")
                print("have another skills ?")
                quition = input("Yes or No").strip().lower()


            get_key_value(members,name,{"age":age,"gender":gender})
            get_key_value(members[name],"Skills",Skills)


print(members)
# Out:
# Mo ha med
# sorry MR.Mo ha med you are not in database
# Do you want to enter your data ?
# {'Mohamed': {'age': '22', 'gender': 'male', 'Skills': {'HTML': '90%', 'CSS': '80%', 'JS': '85%'}}, 'Abdo': {'age': '20', 'gender': 'male', 'Skills': {'HTML': '80%', 'CSS': '90%', 'JS': '70%'}}, 'Nour': {'age': '21', 'gender': 'female', 'Skills': {'HTML': '85%', 'CSS': '70%', 'JS': '90%'}}}

# %%
members = {
    "Mohamed":{"age":"22","gender":"male", "Skills":{"HTML":"90%","CSS":"80%","JS":"85%"}},
    "Abdo":{"age":"20","gender":"male", "Skills":{"HTML":"80%","CSS":"90%","JS":"70%"}},
    "Nour":{"age":"21","gender":"female", "Skills":{"HTML":"85%","CSS":"70%","JS":"90%"}}
    }
print("enter your name : ")
name = input("enter your name : ")
print(name)
print("enter your age : ")
age = input("enter your age : ")
print(age)
print("enter your gender : ")
gender = input("enter your gender : ")
print(gender)
def get_key_value(dect,key,value):
                dect[key]=value
                return dect
            
            
get_key_value(members,name,{"age":age,"gender":gender})
# Out:
# enter your name :
# osama
# enter your age :
# 18
# enter your gender :
# male
# {'Mohamed': {'age': '22',
#   'gender': 'male',
#   'Skills': {'HTML': '90%', 'CSS': '80%', 'JS': '85%'}},
#  'Abdo': {'age': '20',
#   'gender': 'male',
#   'Skills': {'HTML': '80%', 'CSS': '90%', 'JS': '70%'}},
#  'Nour': {'age': '21',
#   'gender': 'female',
#   'Skills': {'HTML': '85%', 'CSS': '70%', 'JS': '90%'}},
#  'osama': {'age': '18', 'gender': 'male'}}

# %%
def get_key_value(dect,key,value):
    dect[key]=value
    return dect
