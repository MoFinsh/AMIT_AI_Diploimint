# %% [markdown]
#  ## 📘Python Assignment – File Operations & Functions
# -   Machine Learning Diploma – Python Module
# -   Instructor: Eng. George Samuel
# -   Week: File Handling & Automation Practice
# -  Assignment Type: Coding + Logical Thinking

# %% [markdown]
# You Name : Mohamed waled abd Elhamid

# %% [markdown]
# 1. Add an item to a tuple

# %%
my_tuple = (1, 2, 3)
item_to_add = 4

# TODO: convert tuple to list, add the item, then convert back to tuple
# your code here
tuple_to_list = list(my_tuple)
tuple_to_list.append(item_to_add)
new_tuple = tuple(tuple_to_list)
print(new_tuple)
# Out:
# (1, 2, 3, 4)

# %% [markdown]
# {Hint}: Tuples cannot change. Convert to list → modify → tuple.

# %% [markdown]
# 2. Sum all the items in a list

# %%
numbers = [5, 10, 15, 20]

# TODO: loop through the list and calculate the total
total = 0
# your code here
for x in numbers:
    total = total + x

print(f"sum numbers in list is : {total}")

# Hint: Use a for loop and accumulate values into total.
# Out:
# sum numbers in list is : 50

# %% [markdown]
# 3. Multiply all items in a list

# %%
numbers = [2, 3, 4]

# TODO: multiply all numbers in the list
result = 1
# your code here
for y in numbers:
    result = result*y
    
print(f"multiplicaction numbers in list is : {result}")
# Hint: Start from 1 and multiply one element at a time.
# Out:
# multiplicaction numbers in list is : 24

# %% [markdown]
# 4. Get the smallest number from a list

# %%
numbers = [10, 3, 25, 1, 7]

# TODO: find smallest value manually (without min())
smallest = numbers[0]
# your code here
for a in numbers:
    if a<smallest:
        smallest =a

print(f"smallest number is : {smallest}")
# Hint: Replace smallest when you find a smaller value.
# Out:
# smallest number is : 1

# %% [markdown]
# 5. Get the largest number from a list

# %%
numbers = [10, 3, 25, 1, 7]

# TODO: find largest value manually (without max())
largest = numbers[0]
# your code here
for a in numbers:
    if a>largest:
        largest =a

print(f"largest number is : {largest}")
# Hint: Same idea as smallest — just check for bigger values.
# Out:
# 25

# %% [markdown]
# 6. Count number of strings with length ≥ 2

# %%
words = ["hi", "a", "hello", "no", "on"]

# TODO: count strings with length >= 2
count = 0
# your code here
for e in words:
 
 if len(e)>=2 :
    count+=1

print(count)
# Hint: Use len(word) and a condition.
# Out:
# 4

# %% [markdown]
# 7. Clone or copy a list

# %%
original = [1, 2, 3, 4]

# TODO: copy the list (not assignment)
# your code here
cloned = []
for f in original:
    cloned .append(f)

print(cloned)
# Hint: Remember: cloned = original is NOT a copy.
# Think of slicing or list().
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# 8. Remove item(s) from a set

# %%
my_set = {1, 2, 3, 4, 5}

# TODO: remove an item using remove() or discard()
# your code here
set_to_list = list(my_set)
set_to_list.remove(set_to_list[4])
my_set = set(set_to_list)
print(my_set)
# Hint: Use remove() or discard().
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# 9. Check if a set is subset of another

# %%
set1 = {1, 2}
set2 = {1, 2, 3, 4}

# TODO: check subset manually or using issubset()
# your code here
is_subset = True
set_lenth = len(set1)
for x in set1:
    if x not in set2:
       print (f"is_subset manual is False")
    
    else:
       print ("is_subset manual is True")

    #    supset function
print(f"is_subset is {set1.issubset(set2)}")
# Hint: Use .issubset() or compare elements manually.
# Out:
# is_subset manual is True
# is_subset manual is True
# is_subset is True

# %% [markdown]
# 10. Remove all elements from a set

# %%
my_set = {1, 2, 3}

# TODO: clear the set
# your code here
my_set.clear()
print(my_set)

# Hint: Sets have a method that makes them empty.
# Out:
# set()

# %% [markdown]
# 11. Find max and min values in a set

# %%
my_set = {10, 3, 25, 1, 7}

# TODO: find max and min manually
# your code here
my_list = list(my_set)

maximum = my_list[0]
minimum = my_list[0]

for x in my_list:
    if x>maximum:
        maximum = x
    else:
        minimum =x 


print("Max:", maximum)
print("Min:", minimum)

# Hint: Convert to a list or loop through items.
# Out:
# Max: 25
# Min: 10

# %% [markdown]
# 12. Find the index of an item in a tuple

# %%
my_tuple = (10, 20, 30, 40)

# TODO: find index of a value (e.g. 30)
# your code here

index_value = my_tuple.index(30)
print(index_value)

# Hint: Tuples have a method for this.
# Out:
# 2

# %% [markdown]
# 13. Convert a tuple to a dictionary

# %%
my_tuple = (("a", 1), ("b", 2), ("c", 3))

# TODO: convert to dictionary
# your code here
my_dict = dict(my_tuple)
print(my_dict)
# Hint: A dictionary can be built directly from pairs.
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# 14. Unzip a list of tuples into individual lists

# %%
pairs = [(1, 2), (3, 4), (5, 6)]

# TODO: extract first elements into one list and second elements into another
# your code here
list1 = []            #with loop 
list2 = []

for a, b  in pairs:
    list1.append(a)
    list2.append(b)
list1,list2 = zip(*pairs)

print(list1)
print(list2)

print("\n")

list1,list2 = zip(*pairs)       #with zip function
print(list1)
print(list2)
# Hint: You can loop OR use zip(*pairs).
# Out:
# (1, 3, 5)
# (2, 4, 6)
#
#
# (1, 3, 5)
# (2, 4, 6)

# %% [markdown]
# 15. Reverse a tuple

# %%
my_tuple = (1, 2, 3, 4, 5)

# TODO: reverse the tuple
# your code here
my_list = list(my_tuple)          #with list way
my_list.reverse()
reversed_tuple = tuple(my_list)
print(reversed_tuple)

reversed_tuple = my_tuple[::-1]      #with slicing way
print(reversed_tuple)
# Hint: Use slicing.
# Out:
# (5, 4, 3, 2, 1)
# (5, 4, 3, 2, 1)

# %% [markdown]
# 16. Convert a list of tuples into a dictionary

# %%
pairs = [("a", 1), ("b", 2), ("c", 3)]

# TODO: convert list of tuples into dictionary
# your code here
my_dict = dict(pairs)
print(my_dict)
# Hint: dict() can convert list-of-pairs formats.
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# 17. Replace the last value of each tuple in a list
#
# - Sample list:
# - [(10, 20, 40), (40, 50, 60), (70, 80, 90)]
# - Expected output:
# - [(10, 20, 100), (40, 50, 100), (70, 80, 100)]

# %%
data = [(10, 20, 40), (40, 50, 60), (70, 80, 90)]

# TODO: replace last value with 100
new_list = []
# your code here

first_tuple = list(data[0])
first_tuple[2] = 100
second_tuple = list(data[1])
second_tuple[2] = 100
third_tuple = list(data[2])
third_tuple[2] = 100

new_tuple1 = tuple(first_tuple)
new_tuple2 = tuple(second_tuple)
new_tuple3 = tuple(third_tuple)

new_list =[new_tuple1, new_tuple2, new_tuple3]
print(new_list)
# Hint: Convert each tuple to list, edit, convert back.
# Out:
# [(10, 20, 100), (40, 50, 100), (70, 80, 100)]

# %% [markdown]
# 18. Sort a tuple by its float element

# %%
items = (("item1", 10.5), ("item2", 5.7), ("item3", 8.9))

# TODO: sort by the float value
# your code here
sorted_items = sorted(items, key = lambda x:x[1])
print(sorted_items)
# Hint: Use sorted() with a key function.
# Out:
# [('item2', 5.7), ('item3', 8.9), ('item1', 10.5)]

# %% [markdown]
# ## challenge part

# %% [markdown]
# Find the longest word in a list

# %%
words = ["hi", "hello", "fantastic", "world"]

# TODO: find the longest word
longest = words[0]
for x in words:
    if x<= longest:
        longest = x

print(f"the longest word is : {longest}")
# Hint: Track the word with the largest len().
# Out:
# the longest word is : fantastic

# %% [markdown]
# Merge two dictionaries

# %%
d1 = {"a": 1, "b": 2}
d2 = {"c": 3, "d": 4}

# TODO: merge into one dictionary

result = {**d1, **d2}   # unpacking way
print(result)


result = d1.copy()      #update way
result.update(d2)

print(result)
# Hint: Use unpacking or update().
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %% [markdown]
# Sum values in a dictionary

# %%
data = {"a": 10, "b": 20, "c": 30}

# TODO: sum all dictionary values

print(total)

# %% [markdown]
# solution

# %%
data = {"a": 10, "b": 20, "c": 30}
#for dictionary i have a key and value so you can loop and find what you need (key or values
total = 0
for value in data.values():
    total += value

print(total)
# Out:
# 60

# %% [markdown]
# New Challenge

# %% [markdown]
# # TODO: sum all scores
# scores = {
#     "student1": {"math": 80, "science": 90},
#     "student2": {"math": 75, "science": 85},
#     "student3": {"math": 92, "science": 88},
# }
#
# total = ___      # TODO: start total at 0
#
# for student_data in scores.___():# TODO: loop over values of the dictionary
#     for score in student_data.___(): # TODO: loop over inner dictionary values
#         total ___ score              # TODO: update the total
#
# print(___)       # TODO: print the result
#
# #hint you will need nested for loop one

# %%
scores = {"student1": {"math": 80, "science": 90},"student2": {"math": 75, "science": 85},"student3": {"math": 92, "science": 88}}


# for loop way
print("\n task with loop way\n")

students_scores_loop = []
for v in scores.values():
    students_scores_loop.append(v)


student_1 = students_scores_loop[0]
student_1_score = 0
for m in student_1.values():
    student_1_score+=m
    
print(f"studint 1 dgree is {student_1} ,total score is {student_1_score}")

student_2 = students_scores_loop[1]
student_2_score = 0
for k in student_2.values():
    student_2_score+=k
    
print(f"studint 2 dgree is {student_2} ,total score is {student_2_score}")

student_3 = students_scores_loop[2]
student_3_score = 0
for k in student_3.values():
    student_3_score+=k
    
print(f"studint 3 dgree is {student_3} ,total score is {student_3_score}")


''''''''''''''''''''''''''''''''''''
# funcition way 
print("\n task with function way\n")


def valuesFun(dict):
    val = []
    for values in dict.values():
        val.append(values)
   
    return val  

students_scores = valuesFun(scores)


student1 = students_scores[0]
student1_score = valuesFun(student1)
total_student1_score = 0
for colect in student1_score:
    total_student1_score += colect

print(f"studint 1 dgree is {student1} ,total score is {total_student1_score}")

student2 = students_scores[1]
student2_score = valuesFun(student2)
total_student2_score = 0
for colect in student2_score:
    total_student2_score += colect

print(f"studint 2 dgree is {student2} ,total score is {total_student2_score}")

student3 = students_scores[2]
student3_score = valuesFun(student3)
total_student3_score = 0
for colect in student3_score:
    total_student3_score += colect

print(f"studint 3 dgree is {student3} ,total score is {total_student3_score}")
# Out:
#  task with loop way
#
# studint 1 dgree is {'math': 80, 'science': 90} ,total score is 170
# studint 2 dgree is {'math': 75, 'science': 85} ,total score is 160
# studint 3 dgree is {'math': 92, 'science': 88} ,total score is 180
#
#  task with function way
#
# studint 1 dgree is {'math': 80, 'science': 90} ,total score is 170
# studint 2 dgree is {'math': 75, 'science': 85} ,total score is 160
# studint 3 dgree is {'math': 92, 'science': 88} ,total score is 180
